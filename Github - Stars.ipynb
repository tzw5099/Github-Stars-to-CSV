# %%
import pandas as pd
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup
import locale
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' ) 
from tqdm import tqdm

# %%
def GitHubStarsToCSV(GitHubUsername):
    df_list = []
    url1 = urlopen("https://github.com/{}?page=1&tab=stars".format(GitHubUsername)).read().decode('utf-8')
    soup = BeautifulSoup(url1, features='lxml')
    last_page = soup.find_all("div","pagination")
    last_page = [l.get_text().split(" ") for l in last_page]
    last_page = int(last_page[0][-2])
    for k in tqdm(range(1,last_page+1)):
        try:
            url = urlopen("https://github.com/{}?page={}&tab=stars".format(GitHubUsername,k)).read().decode('utf-8')
            soup = BeautifulSoup(url, features='lxml')
            all_href = soup.find_all("div","d-inline-block mb-1")
            all_href = [l.a["href"].split("/") for l in all_href]
            all_users = []
            all_repos = []
            url_list = []
            for a,x in enumerate(soup.find_all("div","d-inline-block mb-1")):
                for anchor in x.findAll('a', href=True):
                    url_list.append("{}{}".format("https://github.com/",anchor['href']))

            for x in all_href:
                all_users.append(x[1])
                all_repos.append(x[2])
            all_desc = []
            all_desc_loop = soup.find_all("div","py-1")
            for n,x in enumerate(all_descr_loop):
                if "d-inline-block col-9 text-gray pr-4" in str(x): 
                    for e in (x.find_all("p",itemprop="description")):
                        all_desc.append(e.get_text(strip=True))
                if "d-inline-block col-9 text-gray pr-4" not in str(x): 
                    all_desc.append("")
            all_lang_list = []
            all_lang = soup.find_all("div","f6 text-gray mt-2")
            for n,x in enumerate(all_lang):
                if "programmingLanguage" in str(x): 
                    for e in (x.find_all("span",itemprop="programmingLanguage")):
                        all_lang_list.append(e.get_text(strip=True))
                if "programmingLanguage" not in str(x): 
                    all_lang_list.append("")

            len(all_lang_list)
            all_count_stars = []
            all_count_forks = []
            for a,x in enumerate(soup.find_all("div","f6 text-gray mt-2")):
                if "octicon-repo-forked" in str(x): 
                        for asf,asd in enumerate(x):
                            if "octicon-star" in str(asd): 
                                all_count_stars.append(asd.get_text(strip=True))
                            if "octicon-repo-forked" in str(asd): 
                                all_count_forks.append(asd.get_text(strip=True))
                if "octicon-repo-forked" not in str(x):
                    for asf,asd in enumerate(x):
                        if "octicon-star" in str(asd): 
                                    all_count_stars.append(asd.get_text(strip=True))
                    all_count_forks.append(0)
            all_time = soup.find_all("relative-time")
            all_easy_time = [l.get_text(strip=True) for l in all_time]
            all_time = [l["datetime"] for l in all_time]
            df = pd.DataFrame.from_dict({'repo_url':url_list,'username':all_users,'repos':all_repos,'description':all_desc,'language':all_lang_list,'forks':all_count_forks,'count_stars':all_count_stars, 'easy_time':all_easy_time,'time':all_time})
            df_list.append(df)
        except Exception as e:
            print (str(e))
    return df_list

# %%
def GitHubStarsToCSV(GitHubUsername):
    df_list = []
    url1 = urlopen("https://github.com/{}?page=1&tab=stars".format(GitHubUsername)).read().decode('utf-8')
    soup = BeautifulSoup(url1, features='lxml')
    last_page = soup.find_all("div","pagination")
    last_page = [l.get_text().split(" ") for l in last_page]
    last_page = int(last_page[0][-2])
    for k in tqdm(range(1,last_page+1)):
        print(k)
        try:
            print("https://github.com/{}?page={}&tab=stars".format(GitHubUsername,k))
        except Exception as e:
            print (str(e))
#     return df_list

# %%
df_list = GitHubStarsToCSV("tzw5099")
# Out:
# 100%|██████████| 35/35 [01:11<00:00,  2.05s/it]
# arrays must all be same length

# %%
df = pd.concat(df_list)

# %%
df
# Out:
#                                              repo_url          username  \
# 0   https://github.com//karpathy/arxiv-sanity-pres...          karpathy
# 1    https://github.com//freelawproject/courtlistener    freelawproject
# 2      https://github.com//freelawproject/juriscraper    freelawproject
# 3                    https://github.com//idc9/law-net              idc9
# 4                     https://github.com//google/amss            google
# 5                    https://github.com//joshkyh/amss           joshkyh
# 6    https://github.com//ikatsov/algorithmic-examples           ikatsov
# 7      https://github.com//llSourcell/AI_In_Marketing        llSourcell
# 8                   https://github.com//mautic/mautic            mautic
# 9   https://github.com//portable-cto/side-project-...      portable-cto
# 10                  https://github.com//opencv/opencv            opencv
# 11                      https://github.com//DEAP/deap              DEAP
# 12     https://github.com//JFrankfurt/FundSearch-Tech        JFrankfurt
# 13              https://github.com//buckyroberts/Ella      buckyroberts
# 14  https://github.com//AngryLoki/wikidata-graph-b...         AngryLoki
# 15                  https://github.com//ziyasal/pyley           ziyasal
# 16             https://github.com//dgraph-io/pydgraph         dgraph-io
# 17             https://github.com//cayleygraph/cayley       cayleygraph
# 18               https://github.com//dgraph-io/dgraph         dgraph-io
# 19           https://github.com//usc-isi-i2/Web-Karma        usc-isi-i2
# 20                  https://github.com//mrjbq7/ta-lib            mrjbq7
# 21                  https://github.com//lppkarl/Trady           lppkarl
# 22  https://github.com//malcolm415-zz/technical_an...     malcolm415-zz
# 23   https://github.com//silicon-beach/stock-analysis     silicon-beach
# 24                https://github.com//blaze/datashape             blaze
# 25      https://github.com//pushshift/google_bigquery         pushshift
# 26        https://github.com//thedataincubator/ds30_6  thedataincubator
# 27           https://github.com//freeCodeCamp/devdocs      freeCodeCamp
# 28           https://github.com//saeed349/AlgoTrading          saeed349
# 29       https://github.com//omdv/robinhood-portfolio              omdv
# ..                                                ...               ...
# 0   https://github.com//cyclostationary/exchange_t...   cyclostationary
# 1   https://github.com//PolymathNetwork/polymath-t...   PolymathNetwork
# 2   https://github.com//etherdelta/etherdelta.gith...        etherdelta
# 3        https://github.com//Anorov/cloudflare-scrape            Anorov
# 4           https://github.com//hitbtc-com/hitbtc-api        hitbtc-com
# 5           https://github.com//Crypto-toolbox/hitbtc    Crypto-toolbox
# 6             https://github.com//feedthedogs/EDWatch       feedthedogs
# 7                   https://github.com//tweepy/tweepy            tweepy
# 8             https://github.com//bear/python-twitter              bear
# 9         https://github.com//taspinar/twitterscraper          taspinar
# 10  https://github.com//jburkhardt/GoogleTrendsDas...        jburkhardt
# 11     https://github.com//clintonboys/trendy-scraper       clintonboys
# 12  https://github.com//interworks-morr/wdc-stock-...   interworks-morr
# 13  https://github.com//juancarlosqr/tableau-twitt...      juancarlosqr
# 14       https://github.com//dtreskunov/worldbank-wdc        dtreskunov
# 15  https://github.com//alexfrancisross/TwitterWeb...   alexfrancisross
# 16            https://github.com//coderiot/pyexchange          coderiot
# 17      https://github.com//EthVentures/CryptoTracker       EthVentures
# 18      https://github.com//walkjivefly/LOC-Extension       walkjivefly
# 19      https://github.com//StreisandEffect/streisand   StreisandEffect
# 20                  https://github.com//scrapy/scrapy            scrapy
# 21      https://github.com//pauljherrera/cryptotrader      pauljherrera
# 22  https://github.com//Coinigy/bittrex-websocket-...           Coinigy
# 23  https://github.com//pierrenortje/Coinigy-Web-E...      pierrenortje
# 24  https://github.com//akoukoullis/Coinigy-Price-...       akoukoullis
# 25               https://github.com//celso/coinigyapp             celso
# 26                    https://github.com//Coinigy/api           Coinigy
# 27                      https://github.com//ccxt/ccxt              ccxt
# 28      https://github.com//jestersimpps/cryptotrader      jestersimpps
# 29             https://github.com//rgbkrk/atom-script            rgbkrk
#
#                         repos  \
# 0      arxiv-sanity-preserver
# 1               courtlistener
# 2                 juriscraper
# 3                     law-net
# 4                        amss
# 5                        amss
# 6        algorithmic-examples
# 7             AI_In_Marketing
# 8                      mautic
# 9      side-project-marketing
# 10                     opencv
# 11                       deap
# 12            FundSearch-Tech
# 13                       Ella
# 14     wikidata-graph-builder
# 15                      pyley
# 16                   pydgraph
# 17                     cayley
# 18                     dgraph
# 19                  Web-Karma
# 20                     ta-lib
# 21                      Trady
# 22         technical_analysis
# 23             stock-analysis
# 24                  datashape
# 25            google_bigquery
# 26                     ds30_6
# 27                    devdocs
# 28                AlgoTrading
# 29        robinhood-portfolio
# ..                        ...
# 0        exchange_tax_parsers
# 1              polymath-token
# 2        etherdelta.github.io
# 3           cloudflare-scrape
# 4                  hitbtc-api
# 5                      hitbtc
# 6                     EDWatch
# 7                      tweepy
# 8              python-twitter
# 9              twitterscraper
# 10      GoogleTrendsDashboard
# 11             trendy-scraper
# 12    wdc-stock-price-history
# 13  tableau-twitter-connector
# 14              worldbank-wdc
# 15    TwitterWebDataConnector
# 16                 pyexchange
# 17              CryptoTracker
# 18              LOC-Extension
# 19                  streisand
# 20                     scrapy
# 21               cryptotrader
# 22     bittrex-websocket-feed
# 23        Coinigy-Web-Example
# 24    Coinigy-Price-Converter
# 25                 coinigyapp
# 26                        api
# 27                       ccxt
# 28               cryptotrader
# 29                atom-script
#
#                                           description          language  \
# 0   Web interface for browsing, search and filteri...            Python
# 1   A free and powerful system for awareness and r...            Python
# 2   An API to scrape American court websites for m...              HTML
# 3          code to analyze the legal citation network  Jupyter Notebook
# 4                                                                     R
# 5      Learn Bayesian Regression on simulated dataset                 R
# 6                        Algorithmic Marketing Models  Jupyter Notebook
# 7   This is the code for "AI in Marketing" by Sira...  Jupyter Notebook
# 8   Mautic: Open Source Marketing Automation Softw...               PHP
# 9   A checklist of tactics for marketing your side...
# 10                Open Source Computer Vision Library               C++
# 11      Distributed Evolutionary Algorithms in Python            Python
# 12  A python script that provides a set of hedge f...            Python
# 13                   Self-improving decision organism            Python
# 14               Visualize Wikidata items using d3.js      CoffeeScript
# 15  Python client for an open-source graph databas...            Python
# 16                           Python client for Dgraph            Python
# 17                      An open-source graph database                Go
# 18                         Fast, Distributed Graph DB                Go
# 19                       Information Integration Tool              Java
# 20    Python wrapper for TA-Lib (http://ta-lib.org/).            Python
# 21  Trady is a handy library for computing technic...                C#
# 22  Automated Pattern Recognition w/ Technical Ana...            Python
# 23  Identify patterns in Stock Market for Day Trading  Jupyter Notebook
# 24      Language defining a data description protocol            Python
# 25
# 26  Data Science in 30 minutes with Jess from Quan...  Jupyter Notebook
# 27                          API Documentation Browser              Ruby
# 28     Use the zipline and pyfolio to analyze trades.  Jupyter Notebook
# 29          Portfolio analyzer for Robinhood accounts  Jupyter Notebook
# ..                                                ...               ...
# 0   Web interface for browsing, search and filteri...            Python
# 1   A free and powerful system for awareness and r...        JavaScript
# 2   An API to scrape American court websites for m...              HTML
# 3          code to analyze the legal citation network            Python
# 4                                                                Python
# 5      Learn Bayesian Regression on simulated dataset            Python
# 6                        Algorithmic Marketing Models        JavaScript
# 7   This is the code for "AI in Marketing" by Sira...            Python
# 8   Mautic: Open Source Marketing Automation Softw...            Python
# 9   A checklist of tactics for marketing your side...            Python
# 10                Open Source Computer Vision Library                 R
# 11      Distributed Evolutionary Algorithms in Python            Python
# 12  A python script that provides a set of hedge f...              HTML
# 13                   Self-improving decision organism              HTML
# 14               Visualize Wikidata items using d3.js           Clojure
# 15  Python client for an open-source graph databas...               CSS
# 16                           Python client for Dgraph            Python
# 17                      An open-source graph database            Python
# 18                         Fast, Distributed Graph DB            Python
# 19                       Information Integration Tool             Shell
# 20    Python wrapper for TA-Lib (http://ta-lib.org/).            Python
# 21  Trady is a handy library for computing technic...            Python
# 22  Automated Pattern Recognition w/ Technical Ana...        JavaScript
# 23  Identify patterns in Stock Market for Day Trading        JavaScript
# 24      Language defining a data description protocol        JavaScript
# 25                                                           JavaScript
# 26  Data Science in 30 minutes with Jess from Quan...            Python
# 27                          API Documentation Browser        JavaScript
# 28     Use the zipline and pyfolio to analyze trades.        TypeScript
# 29          Portfolio analyzer for Robinhood accounts        JavaScript
#
#      forks count_stars     easy_time                  time
# 0      635       2,133  May 29, 2018  2018-05-29T11:32:07Z
# 1       52         104   Jul 7, 2018  2018-07-07T06:01:08Z
# 2       29          93   Jul 6, 2018  2018-07-06T23:36:51Z
# 3        4           6  Sep 16, 2017  2017-09-16T02:00:31Z
# 4        7          12   Jun 7, 2018  2018-06-07T21:17:28Z
# 5        0           1  Apr 25, 2018  2018-04-25T11:14:39Z
# 6       11          29  Nov 26, 2017  2017-11-26T19:57:20Z
# 7       19          44   May 4, 2018  2018-05-04T18:31:03Z
# 8      929       2,490   Jul 7, 2018  2018-07-07T23:29:27Z
# 9      386       4,370   Jul 6, 2018  2018-07-06T18:12:46Z
# 10  18,617      25,978   Jul 7, 2018  2018-07-07T15:13:10Z
# 11     476       2,080   Jul 1, 2018  2018-07-01T18:23:17Z
# 12       0           1   Sep 8, 2016  2016-09-08T23:58:27Z
# 13      57         367   Jan 7, 2018  2018-01-07T20:21:16Z
# 14      13          77  May 13, 2016  2016-05-13T21:31:38Z
